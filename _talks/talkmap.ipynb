# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      -------------------------------------- 125.4/125.4 kB 2.5 MB/s eta 0:00:00
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting pygithub
#   Downloading PyGithub-2.3.0-py3-none-any.whl (354 kB)
#      -------------------------------------- 354.4/354.4 kB 2.5 MB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ---------------------------------------- 40.3/40.3 kB 1.9 MB/s eta 0:00:00
# Collecting Deprecated
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting pynacl>=1.4.0
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
#      -------------------------------------- 212.1/212.1 kB 2.6 MB/s eta 0:00:00
# Collecting urllib3>=1.26.0
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      -------------------------------------- 121.4/121.4 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\edenc\appdata\roaming\python\python310\site-packages (from pygithub->getorg) (4.12.2)
# Collecting requests>=2.14.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Collecting pyjwt[crypto]>=2.4.0
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.7.0 in c:\users\edenc\appdata\roaming\python\python310\site-packages (from retrying->getorg) (1.16.0)
# Collecting cryptography>=3.4.0
#   Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 2.7 MB/s eta 0:00:00
# Collecting cffi>=1.4.1
#   Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
#      ------------------------------------ 181.6/181.6 kB 996.4 kB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      -------------------------------------- 66.8/66.8 kB 912.8 kB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#      ------------------------------------ 163.0/163.0 kB 610.9 kB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
#      -------------------------------------- 100.3/100.3 kB 2.9 MB/s eta 0:00:00
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ------------------------------------ 117.6/117.6 kB 984.5 kB/s eta 0:00:00
# Installing collected packages: wrapt, urllib3, retrying, pyjwt, pycparser, idna, geographiclib, charset-normalizer, certifi, requests, geopy, Deprecated, cffi, pynacl, cryptography, pygithub, getorg
# Successfully installed Deprecated-1.2.14 certifi-2024.7.4 cffi-1.16.0 charset-normalizer-3.3.2 cryptography-42.0.8 geographiclib-2.0 geopy-2.4.1 getorg-0.3.1 idna-3.7 pycparser-2.22 pygithub-2.3.0 pyjwt-2.8.0 pynacl-1.5.0 requests-2.32.3 retrying-1.3.4 urllib3-2.2.2 wrapt-1.16.0
# [notice] A new release of pip available: 22.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim(user_agent='edenchen1226@outlook.com')
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Hallbergmoos, Germany
#  Hallbergmoos, Landkreis Freising, Bayern, 85399, Deutschland

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
